# %%
import pandas as pd
import math 
import matplotlib.pyplot as plt
import numpy as np

# %%
result={
    'student':['farhan','rehan','kashan','roban'],
    'numbers':[100,50,50,50]
}
result.values()
# Out:
# dict_values([['farhan', 'rehan', 'kashan', 'roban'], [100, 50, 50, 50]])

# %%
arr=np.array(result)

# %%
#plt.pie(result.get("numbers"),labels=result.get("student"),autopct="%1.1f%%",textprops=dict(c='w'), shadow=True,startangle=90)
plt.pie(result.get("numbers"),labels=result.get("student"),autopct="%1.1f%%",shadow=True)

# %%
plt.bar(result.get("student"),result.get("numbers"))

# %%
fig1 ,ax1=plt.subplots(1,2)
ax1[0].pie(result.get("numbers"),labels=result.get("student"),autopct="%1.1f%%")
#ax1[0,0].legend(result.get("student"), loc ='best',bbox_to_anchor=(1.5, 0.5),borderpad=2)
ax1[1].bar(result.get("student"),result.get("numbers"))
# Out:
# <BarContainer object of 4 artists>

# %%
fig1 ,ax1=plt.subplots()
ax1.pie(result.get("numbers"),labels=result.get("student"),autopct="%1.1f%%")
#ax1[0].legend(loc='best')
# ax1.axis('upper right')
ax1.legend(result.get("student"), loc ='best',bbox_to_anchor=(1.5, 0.5),borderpad=2,title="hints",prop=dict(weight="bold"),fontsize="x-large")
